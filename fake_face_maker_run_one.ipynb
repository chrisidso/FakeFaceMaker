# %%
import shutil
from keras.preprocessing import image
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
import face_controller as fc
import face_transformer as ftf
None

# %%
im1, im2, res = fc.fake_face_generator()

# %%
plt.imshow(res)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0731 10:06:18.387080 140339594258240 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
